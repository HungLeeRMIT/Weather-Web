# %%
import pandas as pd
import psycopg2
import time

# Connect to postgres
dbname = "weather"
user = "root"
password = "root"
host = "localhost"
port = "5401"

# %%
file_path = '../../dataset-Climate/GlobalYearlyLandTempByState.csv'
year_range = range(1960, 2014)
country_col_name = 'Country Code'
debug_print = True

# %%
def custom_print(*args, **kwargs):
    if debug_print:
        print(*args, **kwargs)

# %%
def check_null(amount):
    # Handle NaN values and set amount to NULL
    return None if pd.isna(amount) or pd.isnull(amount) else amount

# %%
yearly_temp_df = pd.read_csv(file_path)
yearly_temp_df.head(1)
# Out:
#    Year  AverageTemperature  MinimumTemperature  MaximumTemperature   State  \
# 0  1750                 NaN                 NaN                 NaN  Adygey
#
#   Country
# 0  Russia

# %%
with psycopg2.connect(
        dbname=dbname,
        user=user,
        password=password,
        host=host,
        port=port
) as connection:
    cursor = connection.cursor()
    query = f"""
    SELECT * FROM country;
"""
    cursor.execute(query)
    all_country = cursor.fetchall()
    country_dict = {name: code for code, name in all_country}

# %%
with psycopg2.connect(
        dbname=dbname,
        user=user,
        password=password,
        host=host,
        port=port
) as connection:
    cursor = connection.cursor()
    query = f"""
    SELECT * FROM state;
"""
    cursor.execute(query)
    all_state = cursor.fetchall()
    state_dict = {state_name: {"id": id, "country_name": country_name} for id, state_name, country_name in all_state}

# %%
def get_state_id(state_name):
    return state_dict[state_name]["id"]

# %%
country_dict
# Out:
# {'Antarctica': 'ATC',
#  'Argentina': 'ARG',
#  'Cambodia': 'KHM',
#  'American Samoa': 'ASM',
#  'Mexico': 'MEX',
#  'Zambia': 'ZMB',
#  'Belize': 'BLZ',
#  'Bulgaria': 'BGR',
#  'Isle Of Man': 'IMN',
#  'Niger': 'NER',
#  'Saudi Arabia': 'SAU',
#  'Botswana': 'BWA',
#  'Tajikistan': 'TJK',
#  'Puerto Rico': 'PRI',
#  'Equatorial Guinea': 'GNQ',
#  'Solomon Islands': 'SLB',
#  'Iceland': 'ISL',
#  'Mauritania': 'MRT',
#  'Burkina Faso': 'BFA',
#  'Ireland': 'IRL',
#  'Federated States Of Micronesia': 'FSM',
#  'Kenya': 'KEN',
#  'Canada': 'CAN',
#  'Sweden': 'SWE',
#  'Croatia': 'HRV',
#  'Dominica': 'DMA',
#  'Austria': 'AUT',
#  'Hungary': 'HUN',
#  'Netherlands': 'NLD',
#  'Japan': 'JPN',
#  'Guatemala': 'GTM',
#  'Comoros': 'COM',
#  'Slovakia': 'SVK',
#  'Gaza Strip': 'PSE',
#  'World': 'WLD',
#  'Congo (Democratic Republic Of The)': 'COD',
#  'Nepal': 'NPL',
#  'Tunisia': 'TUN',
#  'Guam': 'GUM',
#  'Laos': 'LAO',
#  'Italy': 'ITA',
#  'Saint Kitts And Nevis': 'KNA',
#  'Tanzania': 'TZA',
#  'Somalia': 'SOM',
#  'Egypt': 'EGY',
#  'France': 'FRA',
#  'Colombia': 'COL',
#  'Antigua And Barbuda': 'ATG',
#  'Estonia': 'EST',
#  'Cayman Islands': 'CYM',
#  'Bhutan': 'BTN',
#  'Mauritius': 'MUS',
#  'French Polynesia': 'PYF',
#  'Uganda': 'UGA',
#  'El Salvador': 'SLV',
#  'Kyrgyzstan': 'KGZ',
#  'Thailand': 'THA',
#  'Albania': 'ALB',
#  'Panama': 'PAN',
#  'Saint Lucia': 'LCA',
#  'Madagascar': 'MDG',
#  'Togo': 'TGO',
#  'Virgin Islands': 'VIR',
#  'Ghana': 'GHA',
#  'Philippines': 'PHL',
#  'Liberia': 'LBR',
#  'Gabon': 'GAB',
#  'New Zealand': 'NZL',
#  'Guinea': 'GIN',
#  'Ethiopia': 'ETH',
#  'Dominican Republic': 'DOM',
#  'North Korea': 'PRK',
#  'Cameroon': 'CMR',
#  'Rwanda': 'RWA',
#  'Senegal': 'SEN',
#  'Macau': 'MAC',
#  'Israel': 'ISR',
#  'Saint Vincent And The Grenadines': 'VCT',
#  'Honduras': 'HND',
#  'Hong Kong': 'HKG',
#  'Yemen': 'YEM',
#  'Papua New Guinea': 'PNG',
#  'Lesotho': 'LSO',
#  'Pakistan': 'PAK',
#  'Spain': 'ESP',
#  'Afghanistan': 'AFG',
#  'New Caledonia': 'NCL',
#  'Peru': 'PER',
#  'Saint Martin': 'MAF',
#  'Faroe Islands': 'FRO',
#  'Asia': 'SAS',
#  'Andorra': 'AND',
#  'Libya': 'LBY',
#  'Chad': 'TCD',
#  'Finland': 'FIN',
#  'Turkey': 'TUR',
#  'United Kingdom': 'GBR',
#  'Benin': 'BEN',
#  'Kiribati': 'KIR',
#  'Lithuania': 'LTU',
#  'Sierra Leone': 'SLE',
#  'Malawi': 'MWI',
#  'Swaziland': 'SWZ',
#  'Ukraine': 'UKR',
#  'Singapore': 'SGP',
#  'Moldova': 'MDA',
#  'Macedonia': 'MKD',
#  'Eritrea': 'ERI',
#  'Belarus': 'BLR',
#  'Ecuador': 'ECU',
#  'Samoa': 'WSM',
#  'Paraguay': 'PRY',
#  'Zimbabwe': 'ZWE',
#  'United States': 'USA',
#  'Armenia': 'ARM',
#  'Lebanon': 'LBN',
#  'Sao Tome And Principe': 'STP',
#  'Northern Mariana Islands': 'MNP',
#  'Burma': 'MMR',
#  'Uruguay': 'URY',
#  'Suriname': 'SUR',
#  'Aruba': 'ABW',
#  'Portugal': 'PRT',
#  'South Korea': 'KOR',
#  'Turks And Caicas Islands': 'TCA',
#  'Liechtenstein': 'LIE',
#  'Iraq': 'IRQ',
#  'Guinea Bissau': 'GNB',
#  'British Virgin Islands': 'VGB',
#  'Czech Republic': 'CZE',
#  'Bangladesh': 'BGD',
#  'Palau': 'PLW',
#  'Algeria': 'DZA',
#  'Bahrain': 'BHR',
#  'Oman': 'OMN',
#  'Timor Leste': 'TLS',
#  'Malta': 'MLT',
#  'Fiji': 'FJI',
#  'Trinidad And Tobago': 'TTO',
#  'Turkmenistan': 'TKM',
#  'Cuba': 'CUB',
#  'Kazakhstan': 'KAZ',
#  'Greenland': 'GRL',
#  'Gambia': 'GMB',
#  'Kuwait': 'KWT',
#  'Sint Maarten': 'SXM',
#  'Belgium': 'BEL',
#  'Poland': 'POL',
#  'Jamaica': 'JAM',
#  'Grenada': 'GRD',
#  'Guyana': 'GUY',
#  'Latvia': 'LVA',
#  'Mongolia': 'MNG',
#  'Monaco': 'MCO',
#  'Vietnam': 'VNM',
#  'Germany': 'DEU',
#  'Denmark': 'DNK',
#  'Syria': 'SYR',
#  'Nicaragua': 'NIC',
#  'Sudan': 'SDN',
#  'Malaysia': 'MYS',
#  'Sri Lanka': 'LKA',
#  'Jordan': 'JOR',
#  'Mozambique': 'MOZ',
#  'Bahamas': 'BHS',
#  'Serbia': 'SRB',
#  'Uzbekistan': 'UZB',
#  'Greece': 'GRC',
#  'Burundi': 'BDI',
#  'China': 'CHN',
#  'Iran': 'IRN',
#  'Haiti': 'HTI',
#  'United Arab Emirates': 'ARE',
#  'Montenegro': 'MNE',
#  'India': 'IND',
#  'Bosnia And Herzegovina': 'BIH',
#  'Bolivia': 'BOL',
#  'Luxembourg': 'LUX',
#  'Slovenia': 'SVN',
#  'Angola': 'AGO',
#  'Venezuela': 'VEN',
#  'Australia': 'AUS',
#  "Côte D'Ivoire": 'CIV',
#  'Russia': 'RUS',
#  'Cyprus': 'CYP',
#  'Djibouti': 'DJI',
#  'Morocco': 'MAR',
#  'Romania': 'ROU',
#  'Namibia': 'NAM',
#  'Chile': 'CHL',
#  'Indonesia': 'IDN',
#  'Seychelles': 'SYC',
#  'Azerbaijan': 'AZE',
#  'Switzerland': 'CHE',
#  'Congo': 'COG',
#  'Mali': 'MLI',
#  'Nigeria': 'NGA',
#  'South Africa': 'ZAF',
#  'Norway': 'NOR',
#  'Qatar': 'QAT',
#  'Tonga': 'TON',
#  'Costa Rica': 'CRI',
#  'San Marino': 'SMR',
#  'Brazil': 'BRA',
#  'Central African Republic': 'CAF',
#  'Georgia': 'GEO',
#  'Barbados': 'BRB',
#  'Cape Verde': 'CPV'}

# %%
def get_country_code(country_name):
    return country_dict[country_name]

# %%
def check_state_exist(connection, state_name, country_name):
    cursor = connection.cursor()
    country_code = get_country_code(country_name)
    check_query = f"""
        SELECT 1
        FROM state
        WHERE name = %s and country_code = %s
        LIMIT 1;
    """
    # start_time_exec_and_fetchone = time.time()
    cursor.execute(check_query, (state_name, country_code))
    result = cursor.fetchone()
    return result is not None

# %%
def add_state_to_country(connection, row):
    cursor = connection.cursor()
    
    state = row["State"]
    country = row["Country"]
    

    if check_state_exist(connection, state, country):
        print("state exist")
        return 0
    insert_query = f"""
            INSERT INTO state (
                name, country_code
            )
            VALUES (
                # %s, %s
            );
        """
    cursor.execute(insert_query, (state, get_country_code(country)))
    connection.commit()
    return 1

# %%
def temp_exists(connection, state_name, year, country_name):
    cursor = connection.cursor()

    country_code = get_country_code(country_name)

    check_query = """
        SELECT 1
        FROM temperature
        WHERE state_id = %s
        AND year = %s
        AND country_code = %s
        
        LIMIT 1;
    """
    cursor.execute(check_query, (get_state_id(state_name), year, country_code))
    result = cursor.fetchone()
    cursor.close()

    return result is not None

# %%
def add_state_temp(connection, row):
    cursor = connection.cursor()
    state = row["State"]
    country = row["Country"]
    year = row["Year"]
    average_temp = check_null(row['AverageTemperature'])
    min_temp = check_null(row['MinimumTemperature'])
    max_temp = check_null(row['MaximumTemperature'])

    is_temp_exists = temp_exists(connection, state, year, country)
    state_id = get_state_id(state)
    country_code = get_country_code(country)
    if is_temp_exists:
        print("temp_exist: ", state_id, year, country_code)
        return 0
    
    insert_query = f"""
            INSERT INTO temperature (
                year, state_id, country_code,
                average_temp, min_temp, max_temp
            )
            VALUES (
               # %s, %s, %s,
               # %s, %s, %s
            );
        """
    
    cursor.execute(insert_query,
                   (year, state_id, country_code,
                    average_temp, min_temp, max_temp))
    return 1

# %%
# Establish a connection to the PostgreSQL database
try:
    connection = psycopg2.connect(
        dbname=dbname,
        user=user,
        password=password,
        host=host,
        port=port
    )

    total_insert = 0
    for index, row in yearly_temp_df.iterrows():
        total_insert += add_state_temp(connection, row)
        # total_insert += add_state_to_country(connection, row)
        
    connection.commit()
    connection.close()

    print(f"Data inserted successfully! Total inserts: {total_insert}")


except psycopg2.Error as e:
    print(f"Error connecting to PostgreSQL: {e}")
# Out:
# Data inserted successfully! Total inserts: 53415

# %%
unique_combinations = yearly_temp_df[['State', 'Country']].drop_duplicates()
unique_combinations
# Out:
#                     State        Country
# 0                  Adygey         Russia
# 1                 Alabama  United States
# 2            Arkhangel'Sk         Russia
# 3                Belgorod         Russia
# 4                 Bryansk         Russia
# ...                   ...            ...
# 14639   Western Australia      Australia
# 15124                Acre         Brazil
# 15270  Northern Territory      Australia
# 15294          Queensland      Australia
# 21904              Hawaii  United States
#
# [241 rows x 2 columns]

# %%
yearly_temp_df
# Out:
#        Year  AverageTemperature  MinimumTemperature  MaximumTemperature  \
# 0      1750                 NaN                 NaN                 NaN
# 1      1750              17.653               6.950              28.464
# 2      1750              -1.366             -15.102              13.995
# 3      1750               6.974              -7.352              21.723
# 4      1750               6.284              -7.521              19.975
# ...     ...                 ...                 ...                 ...
# 53410  2013               5.618             -10.928              18.411
# 53411  2013               2.445             -24.428              21.207
# 53412  2013              -2.819             -22.899              12.458
# 53413  2013              17.597               9.053              21.860
# 53414  2013              18.200               5.120              29.272
#
#               State        Country
# 0            Adygey         Russia
# 1           Alabama  United States
# 2      Arkhangel'Sk         Russia
# 3          Belgorod         Russia
# 4           Bryansk         Russia
# ...             ...            ...
# 53410    Yaroslavl'         Russia
# 53411        Yevrey         Russia
# 53412         Yukon         Canada
# 53413        Yunnan          China
# 53414      Zhejiang          China
#
# [53415 rows x 6 columns]
